# %%
file = './af3_output/prg1_screen/20250518/merged_pae_scores.tsv'

with open(file, 'r') as f : 
    for line in f : 
        if not line.startswith("pae") :
            info = line.strip().split("\t")
            pae_min = info[0]
            gene_info = info[1]
            gene1 = gene_info.split("_")[0]
            gene2 = gene_info.split("_")[2]
